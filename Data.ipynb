# %%
import numpy as np
import pandas as pd
import os
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
data_forbes = pd.read_csv("myDataFrame.csv")

# %%
data_forbes.head()
# Out:
#                  Company name  \
# 0  Global Logistic Properties
# 1                        ICBC
# 2                   BMW Group
# 3             Cheniere Energy
# 4                 TripAdvisor
#
#                                          Description  \
# 0  Global Logistic Properties Ltd. operates as an...
# 1  Industrial & Commercial Bank of China Ltd. eng...
# 2  Bayerische Motoren Werke AG engages in the man...
# 3  Cheniere Energy, Inc. is engaged in the develo...
# 4  TripAdvisor, Inc. is an online travel research...
#
#                      Industrial
# 0                   Real Estate
# 1                   Major Banks
# 2    Auto & Truck Manufacturers
# 3          Oil & Gas Operations
# 4  Business & Personal Services

# %%
categories = Counter(data_forbes.Industrial)

# %%
print(categories)
# Out:
# Counter({'Regional Banks': 242, 'Oil & Gas Operations': 96, 'Electric Utilities': 90, 'Real Estate': 73, 'Investment Services': 70, 'Telecommunications services': 63, 'Major Banks': 60, 'Construction Services': 51, 'Diversified Insurance': 49, 'Food Processing': 46, 'Diversified Metals & Mining': 42, 'Iron & Steel': 41, 'Pharmaceuticals': 41, 'Conglomerates': 39, 'Food Retail': 37, 'Life & Health Insurance': 35, 'Specialized Chemicals': 34, 'Diversified Chemicals': 32, 'Electronics': 29, 'Auto & Truck Parts': 29, 'Semiconductors': 29, 'Beverages': 28, 'Auto & Truck Manufacturers': 27, 'Business & Personal Services': 27, 'Heavy Equipment': 26, 'Oil Services & Equipment': 26, 'Property & Casualty Insurance': 25, 'Broadcasting & Cable': 25, 'Household/Personal Care': 25, 'Specialty Stores': 24, 'Computer Services': 23, 'Airline': 22, 'Other Industrial Equipment': 22, 'Other Transportation': 21, 'Construction Materials': 21, 'Medical Equipment & Supplies': 20, 'Aerospace & Defense': 20, 'Software & Programming': 18, 'Railroads': 17, 'Trading Companies': 16, 'Consumer Financial Services': 16, 'Natural Gas Utilities': 15, 'Electrical Equipment': 14, 'Apparel/Accessories': 14, 'Apparel/Footwear Retail': 13, 'Computer Hardware': 12, 'Healthcare Services': 12, 'Department Stores': 12, 'Consumer Electronics': 12, 'Biotechs': 11, 'Hotels & Motels': 11, 'Recreational Products': 11, 'Tobacco': 10, 'Printing & Publishing': 9, 'Casinos & Gaming': 9, 'Restaurants': 9, 'Discount Stores': 9, 'Paper & Paper Products': 8, 'Diversified Utilities': 8, 'Communications Equipment': 8, 'Home Improvement Retail': 6, 'Aluminum': 6, 'Computer Storage Devices': 6, 'Household Appliances': 6, 'Containers & Packaging': 5, 'Internet & Catalog Retail': 5, 'Rental & Leasing': 5, 'Advertising': 5, 'Thrifts & Mortgage Finance': 5, 'Managed Health Care': 5, 'Trucking': 4, 'Business Products & Supplies': 4, 'Air Courier': 4, 'Computer & Electronics Retail': 4, 'Drug Retail': 4, 'Security Systems': 3, 'Furniture & Fixtures': 3, 'Precision Healthcare Equipment': 3, 'Insurance Brokers': 3, '2006': 2, '2002': 2, '2013': 2, 'Retailing': 2, 'United States': 2, 'Environmental & Waste': 2, 'Forest Products': 1, '2012': 1, '2007': 1, 'Vietnam': 1, '1984': 1, '1976': 1, 'Netherlands': 1, 'Diversified Media': 1, '2001': 1, '1980': 1, '1977': 1, 'China': 1, '1987': 1, '1988': 1, '1983': 1, '1998': 1})

# %%
fig, ax = plt.subplots(figsize=(10,20))
g = sns.countplot(y="Industrial", data=data_forbes)
plt.title('TRAIN DATA')
plt.tight_layout()
plt.show()
